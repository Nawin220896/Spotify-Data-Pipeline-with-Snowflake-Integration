# %%
# !pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.25.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting redis>=3.5.3 (from spotipy)
#   Downloading redis-5.2.1-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: requests>=2.25.0 in c:\users\navee\anaconda3\lib\site-packages (from spotipy) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\navee\anaconda3\lib\site-packages (from spotipy) (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\navee\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\navee\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\navee\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2024.12.14)
# Downloading spotipy-2.25.0-py3-none-any.whl (30 kB)
# Downloading redis-5.2.1-py3-none-any.whl (261 kB)
# Installing collected packages: redis, spotipy
# Successfully installed redis-5.2.1 spotipy-2.25.0

# %%
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credentials_manager=SpotifyClientCredentials(client_id="#",client_secret="#")

# %%
sp = spotipy.Spotify(auth_manager=client_credential_manager)

# %%
playlist_link="https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF"

# %%
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
playlist_link='https://open.spotify.com/playlist/1d2fAul5T010POHxi1bQ4i'
playlist_URI=playlist_link.split('/')[-1]
playlist_URI
# Out:
# '1d2fAul5T010POHxi1bQ4i'

# %%
data=sp.playlist_tracks(playlist_URI)

# %%
uri = playlist_link.split("/")[-1].split("?")[0]
print(uri)
# Out:
# 37i9dQZEVXbNG2KDcFcKOF

# %%
album_list=[]
for row in data['items']:
    album_id= row['track']['album']['id']
    album_name=row['track']['album']['name']
    album_release_date=row['track']['album']['release_date']
    album_total_tracks=row['track']['album']['total_tracks']
    album_url=row['track']['album']['external_urls']['spotify']
    album_element={'album_id':album_id, 'album_name':album_name, 'album_release_date':album_release_date,'album_total_tracks':album_total_tracks, 'album_url':album_url}

    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '61ulfFSmmxMhc2wCdmdMkN',
#   'album_name': 'Merry Christmas',
#   'album_release_date': '1994-10-28',
#   'album_total_tracks': 10,
#   'album_url': 'https://open.spotify.com/album/61ulfFSmmxMhc2wCdmdMkN'},
#  {'album_id': '6egzU9NKfora01qaNbvwfZ',
#   'album_name': 'LAST CHRISTMAS',
#   'album_release_date': '1984-11-29',
#   'album_total_tracks': 3,
#   'album_url': 'https://open.spotify.com/album/6egzU9NKfora01qaNbvwfZ'},
#  {'album_id': '34wa3zf2prXFMk47t9zHFG',
#   'album_name': 'Merry Christmas From Brenda Lee',
#   'album_release_date': '1964-10-19',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/34wa3zf2prXFMk47t9zHFG'},
#  {'album_id': '3wivyOdotHWZ9dcuXMjPKT',
#   'album_name': 'Jingle Bell Rock/Captain Santa Claus (And His Reindeer Space Patrol)',
#   'album_release_date': '1957-12-02',
#   'album_total_tracks': 2,
#   'album_url': 'https://open.spotify.com/album/3wivyOdotHWZ9dcuXMjPKT'},
#  {'album_id': '10FLjwfpbxLmW8c25Xyc2N',
#   'album_name': 'Die With A Smile',
#   'album_release_date': '2024-08-16',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'},
#  {'album_id': '27MNgBEnLCKoafz1g2Zu97',
#   'album_name': 'Santa Tell Me',
#   'album_release_date': '2014-11-24',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/27MNgBEnLCKoafz1g2Zu97'},
#  {'album_id': '7kFyd5oyJdVX2pIi6P4iHE',
#   'album_name': 'rosie',
#   'album_release_date': '2024-12-06',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/7kFyd5oyJdVX2pIi6P4iHE'},
#  {'album_id': '5I48ENiZiaZZSOpec6PdS5',
#   'album_name': 'A Winter Romance',
#   'album_release_date': '1959-01-01',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/5I48ENiZiaZZSOpec6PdS5'},
#  {'album_id': '7Jahqd1kx9Qau0E9x9iZj6',
#   'album_name': 'Wrapped In Red',
#   'album_release_date': '2013-10-29',
#   'album_total_tracks': 14,
#   'album_url': 'https://open.spotify.com/album/7Jahqd1kx9Qau0E9x9iZj6'},
#  {'album_id': '2vcGYJcPfXUmCdcXXqqukg',
#   'album_name': 'Everyday Is Christmas (Deluxe Edition)',
#   'album_release_date': '2018-11-01',
#   'album_total_tracks': 13,
#   'album_url': 'https://open.spotify.com/album/2vcGYJcPfXUmCdcXXqqukg'},
#  {'album_id': '4dcJHxlOJwtyypL7sx1qch',
#   'album_name': 'The Andy Williams Christmas Album',
#   'album_release_date': '1963-11-24',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/4dcJHxlOJwtyypL7sx1qch'},
#  {'album_id': '3No96PtEFyRfX1oELmZTPu',
#   'album_name': 'Feliz Navidad',
#   'album_release_date': '2002-09-24',
#   'album_total_tracks': 15,
#   'album_url': 'https://open.spotify.com/album/3No96PtEFyRfX1oELmZTPu'},
#  {'album_id': '53fJVD9LpBKEMqdAF7PW5K',
#   'album_name': 'Christmas (Deluxe Special Edition)',
#   'album_release_date': '2011-10-24',
#   'album_total_tracks': 21,
#   'album_url': 'https://open.spotify.com/album/53fJVD9LpBKEMqdAF7PW5K'},
#  {'album_id': '3aYOF3HVkIr1IzhePfQS7s',
#   'album_name': 'Sleigh Ride',
#   'album_release_date': '2020-12-04',
#   'album_total_tracks': 15,
#   'album_url': 'https://open.spotify.com/album/3aYOF3HVkIr1IzhePfQS7s'},
#  {'album_id': '0hBRqPYPXhr1RkTDG3n4Mk',
#   'album_name': 'The Secret of Us (Deluxe)',
#   'album_release_date': '2024-10-18',
#   'album_total_tracks': 20,
#   'album_url': 'https://open.spotify.com/album/0hBRqPYPXhr1RkTDG3n4Mk'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'album_name': 'HIT ME HARD AND SOFT',
#   'album_release_date': '2024-05-17',
#   'album_total_tracks': 10,
#   'album_url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '53fJVD9LpBKEMqdAF7PW5K',
#   'album_name': 'Christmas (Deluxe Special Edition)',
#   'album_release_date': '2011-10-24',
#   'album_total_tracks': 21,
#   'album_url': 'https://open.spotify.com/album/53fJVD9LpBKEMqdAF7PW5K'},
#  {'album_id': '3NoP1ifIejWkGSDsO9T2xH',
#   'album_name': 'The Nat King Cole Story',
#   'album_release_date': '1961-09-25',
#   'album_total_tracks': 36,
#   'album_url': 'https://open.spotify.com/album/3NoP1ifIejWkGSDsO9T2xH'},
#  {'album_id': '3cr4Xgz8nnfp7iYbVqwzzH',
#   'album_name': 'Under The Mistletoe',
#   'album_release_date': '2011-01-01',
#   'album_total_tracks': 11,
#   'album_url': 'https://open.spotify.com/album/3cr4Xgz8nnfp7iYbVqwzzH'},
#  {'album_id': '48rypPDKdKiusMXKaYcEGV',
#   'album_name': 'McCartney II (Special Edition)',
#   'album_release_date': '1980-05-16',
#   'album_total_tracks': 19,
#   'album_url': 'https://open.spotify.com/album/48rypPDKdKiusMXKaYcEGV'},
#  {'album_id': '555NIhJIQ4XoS5N7VglF0v',
#   'album_name': 'Signature Box',
#   'album_release_date': '2010-10-05',
#   'album_total_tracks': 119,
#   'album_url': 'https://open.spotify.com/album/555NIhJIQ4XoS5N7VglF0v'},
#  {'album_id': '15XcLhiVMlSOipUddTNDnr',
#   'album_name': 'MUSE',
#   'album_release_date': '2024-07-19',
#   'album_total_tracks': 7,
#   'album_url': 'https://open.spotify.com/album/15XcLhiVMlSOipUddTNDnr'},
#  {'album_id': '4lculT3R9mxFqdmXOCLuY7',
#   'album_name': 'Greatest Christmas Songs',
#   'album_release_date': '1999-08-23',
#   'album_total_tracks': 21,
#   'album_url': 'https://open.spotify.com/album/4lculT3R9mxFqdmXOCLuY7'},
#  {'album_id': '3mJm77zryIt06nbQV7DjuY',
#   'album_name': '+-=÷× (Tour Collection)',
#   'album_release_date': '2024-09-27',
#   'album_total_tracks': 25,
#   'album_url': 'https://open.spotify.com/album/3mJm77zryIt06nbQV7DjuY'},
#  {'album_id': '1Ss0ArMRr91m83mOgRBjSZ',
#   'album_name': 'GNX',
#   'album_release_date': '2024-11-21',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/1Ss0ArMRr91m83mOgRBjSZ'},
#  {'album_id': '2jCRKrNZVbG2lGMs0S9Opa',
#   'album_name': 'Merry Christmas Everyone',
#   'album_release_date': '1991-11-25',
#   'album_total_tracks': 13,
#   'album_url': 'https://open.spotify.com/album/2jCRKrNZVbG2lGMs0S9Opa'},
#  {'album_id': '2WlRAsKdyYOwg2tdBjxVwq',
#   'album_name': 'Do They Know It’s Christmas?',
#   'album_release_date': '1984-11-25',
#   'album_total_tracks': 2,
#   'album_url': 'https://open.spotify.com/album/2WlRAsKdyYOwg2tdBjxVwq'},
#  {'album_id': '3rDo7fQDUwJ6qmxwP5yQsY',
#   'album_name': 'Home Alone (Original Motion Picture Soundtrack)',
#   'album_release_date': '1990',
#   'album_total_tracks': 19,
#   'album_url': 'https://open.spotify.com/album/3rDo7fQDUwJ6qmxwP5yQsY'},
#  {'album_id': '3miX7IkmfMBJhQejq5rsA6',
#   'album_name': 'Christmas (Baby, Please Come Home)',
#   'album_release_date': '2020-12-04',
#   'album_total_tracks': 15,
#   'album_url': 'https://open.spotify.com/album/3miX7IkmfMBJhQejq5rsA6'},
#  {'album_id': '2B9FcHKqz3PWJlh0yGnmM7',
#   'album_name': 'The Classic Christmas Album',
#   'album_release_date': '1945',
#   'album_total_tracks': 14,
#   'album_url': 'https://open.spotify.com/album/2B9FcHKqz3PWJlh0yGnmM7'},
#  {'album_id': '5tR0alqUd1KMW37vPnsOC4',
#   'album_name': 'Dancing with Strangers (Deluxe Edition, 2019 Remaster)',
#   'album_release_date': '1987-08-02',
#   'album_total_tracks': 28,
#   'album_url': 'https://open.spotify.com/album/5tR0alqUd1KMW37vPnsOC4'},
#  {'album_id': '68CN2LzY8MoxO2udy2C22e',
#   'album_name': 'Sailor Song',
#   'album_release_date': '2024-07-26',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/68CN2LzY8MoxO2udy2C22e'},
#  {'album_id': '1Ph9nV8cNv7Gq7yHOlmbgh',
#   'album_name': 'Spotify Singles Holiday',
#   'album_release_date': '2023-11-14',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/1Ph9nV8cNv7Gq7yHOlmbgh'},
#  {'album_id': '42KK3F8HTm1dyv5iFsCXdw',
#   'album_name': 'White Christmas',
#   'album_release_date': '1945-01-01',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/42KK3F8HTm1dyv5iFsCXdw'},
#  {'album_id': '6zk4RKl6JFlgLCV4Z7DQ7N',
#   'album_name': "Elvis' Christmas Album",
#   'album_release_date': '1957-10-15',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/6zk4RKl6JFlgLCV4Z7DQ7N'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'album_name': "Short n' Sweet",
#   'album_release_date': '2024-08-23',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'},
#  {'album_id': '2D2boDrCPl6idtxpJF6r38',
#   'album_name': 'A Nonsense Christmas',
#   'album_release_date': '2022-12-07',
#   'album_total_tracks': 2,
#   'album_url': 'https://open.spotify.com/album/2D2boDrCPl6idtxpJF6r38'},
#  {'album_id': '1DILNh7maaYyKxe15V9xLq',
#   'album_name': "Rock 'N' Roll Rarities",
#   'album_release_date': '1986-01-01',
#   'album_total_tracks': 20,
#   'album_url': 'https://open.spotify.com/album/1DILNh7maaYyKxe15V9xLq'},
#  {'album_id': '2IRxVVqbSbqHJo8Zx50LYn',
#   'album_name': 'Timeless',
#   'album_release_date': '2024-09-27',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/2IRxVVqbSbqHJo8Zx50LYn'},
#  {'album_id': '3sId8sOH47yqOWopzbEtJn',
#   'album_name': 'A Pentatonix Christmas Deluxe',
#   'album_release_date': '2017-12-06',
#   'album_total_tracks': 16,
#   'album_url': 'https://open.spotify.com/album/3sId8sOH47yqOWopzbEtJn'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'album_name': 'HIT ME HARD AND SOFT',
#   'album_release_date': '2024-05-17',
#   'album_total_tracks': 10,
#   'album_url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '0ny6mZMBrYSO0s8HAKbcVq',
#   'album_name': 'A Jolly Christmas From Frank Sinatra',
#   'album_release_date': '1957-09',
#   'album_total_tracks': 15,
#   'album_url': 'https://open.spotify.com/album/0ny6mZMBrYSO0s8HAKbcVq'},
#  {'album_id': '6SEtGOi92yZM5TyAGlXlpZ',
#   'album_name': "Santa Claus Is Comin' to Town (Live at C.W. Post College, Greenvale, NY - December 1975)",
#   'album_release_date': '1981',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/6SEtGOi92yZM5TyAGlXlpZ'},
#  {'album_id': '5sVFXIMrFRKBtDOexVlBBU',
#   'album_name': 'When Christmas Comes Around...',
#   'album_release_date': '2021-10-15',
#   'album_total_tracks': 15,
#   'album_url': 'https://open.spotify.com/album/5sVFXIMrFRKBtDOexVlBBU'},
#  {'album_id': '60cQzWfmdg4hyDXrpW6kOA',
#   'album_name': 'Tu Boda',
#   'album_release_date': '2024-09-26',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/60cQzWfmdg4hyDXrpW6kOA'},
#  {'album_id': '1pSxnWkixgHxo9jnGK66nb',
#   'album_name': 'Run Rudolph Run - Spotify Singles Holiday',
#   'album_release_date': '2024-10-15',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/1pSxnWkixgHxo9jnGK66nb'},
#  {'album_id': '0ny6mZMBrYSO0s8HAKbcVq',
#   'album_name': 'A Jolly Christmas From Frank Sinatra',
#   'album_release_date': '1957-09',
#   'album_total_tracks': 15,
#   'album_url': 'https://open.spotify.com/album/0ny6mZMBrYSO0s8HAKbcVq'},
#  {'album_id': '67nqYhvjDyJXGD64937Lw3',
#   'album_name': "The Beach Boys' Christmas Album",
#   'album_release_date': '1964-11-09',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/67nqYhvjDyJXGD64937Lw3'},
#  {'album_id': '2R5dzEQT6MDsnwiZSpWgqC',
#   'album_name': 'Caribou (Remastered 1995)',
#   'album_release_date': '1974-06-28',
#   'album_total_tracks': 14,
#   'album_url': 'https://open.spotify.com/album/2R5dzEQT6MDsnwiZSpWgqC'},
#  {'album_id': '5ylbxH7EqpsmHZCRuiYewS',
#   'album_name': 'Si Antes Te Hubiera Conocido',
#   'album_release_date': '2024-06-21',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/5ylbxH7EqpsmHZCRuiYewS'}]

# %%
artist_list=[]
for row in data['items']:
    for artist in row['track']['artists']:
        artist_dict={'artist_id':artist['id'],'artist_name':artist['name'],'external_url':artist['href']}
        artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '4iHNK0tOyZPYnBU7nGAgpQ',
#   'artist_name': 'Mariah Carey',
#   'external_url': 'https://api.spotify.com/v1/artists/4iHNK0tOyZPYnBU7nGAgpQ'},
#  {'artist_id': '5lpH0xAS4fVfLkACg9DAuM',
#   'artist_name': 'Wham!',
#   'external_url': 'https://api.spotify.com/v1/artists/5lpH0xAS4fVfLkACg9DAuM'},
#  {'artist_id': '4cPHsZM98sKzmV26wlwD2W',
#   'artist_name': 'Brenda Lee',
#   'external_url': 'https://api.spotify.com/v1/artists/4cPHsZM98sKzmV26wlwD2W'},
#  {'artist_id': '38EmEgXkgK51MT2tPY0EoC',
#   'artist_name': 'Bobby Helms',
#   'external_url': 'https://api.spotify.com/v1/artists/38EmEgXkgK51MT2tPY0EoC'},
#  {'artist_id': '1HY2Jd0NmPuamShAr6KMms',
#   'artist_name': 'Lady Gaga',
#   'external_url': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_url': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '66CXWjxzNUsdJxJ2JdwvnR',
#   'artist_name': 'Ariana Grande',
#   'external_url': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR'},
#  {'artist_id': '3eVa5w3URK5duf6eyVDbu9',
#   'artist_name': 'ROSÉ',
#   'external_url': 'https://api.spotify.com/v1/artists/3eVa5w3URK5duf6eyVDbu9'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_url': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '49e4v89VmlDcFCMyDv9wQ9',
#   'artist_name': 'Dean Martin',
#   'external_url': 'https://api.spotify.com/v1/artists/49e4v89VmlDcFCMyDv9wQ9'},
#  {'artist_id': '3BmGtnKgCSGYIUhmivXKWX',
#   'artist_name': 'Kelly Clarkson',
#   'external_url': 'https://api.spotify.com/v1/artists/3BmGtnKgCSGYIUhmivXKWX'},
#  {'artist_id': '5WUlDfRSoLAfcVSX1WnrxN',
#   'artist_name': 'Sia',
#   'external_url': 'https://api.spotify.com/v1/artists/5WUlDfRSoLAfcVSX1WnrxN'},
#  {'artist_id': '4sj6D0zlMOl25nprDJBiU9',
#   'artist_name': 'Andy Williams',
#   'external_url': 'https://api.spotify.com/v1/artists/4sj6D0zlMOl25nprDJBiU9'},
#  {'artist_id': '7K78lVZ8XzkjfRSI7570FF',
#   'artist_name': 'José Feliciano',
#   'external_url': 'https://api.spotify.com/v1/artists/7K78lVZ8XzkjfRSI7570FF'},
#  {'artist_id': '1GxkXlMwML1oSg5eLPiAz3',
#   'artist_name': 'Michael Bublé',
#   'external_url': 'https://api.spotify.com/v1/artists/1GxkXlMwML1oSg5eLPiAz3'},
#  {'artist_id': '7CyeXFnOrfC1N6z4naIpgo',
#   'artist_name': 'The Ronettes',
#   'external_url': 'https://api.spotify.com/v1/artists/7CyeXFnOrfC1N6z4naIpgo'},
#  {'artist_id': '4tuJ0bMpJh08umKkEXKUI5',
#   'artist_name': 'Gracie Abrams',
#   'external_url': 'https://api.spotify.com/v1/artists/4tuJ0bMpJh08umKkEXKUI5'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '1GxkXlMwML1oSg5eLPiAz3',
#   'artist_name': 'Michael Bublé',
#   'external_url': 'https://api.spotify.com/v1/artists/1GxkXlMwML1oSg5eLPiAz3'},
#  {'artist_id': '7v4imS0moSyGdXyLgVTIV7',
#   'artist_name': 'Nat King Cole',
#   'external_url': 'https://api.spotify.com/v1/artists/7v4imS0moSyGdXyLgVTIV7'},
#  {'artist_id': '1uNFoZAHBGtllmzznpCI3s',
#   'artist_name': 'Justin Bieber',
#   'external_url': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s'},
#  {'artist_id': '4STHEaNw4mPZ2tzheohgXB',
#   'artist_name': 'Paul McCartney',
#   'external_url': 'https://api.spotify.com/v1/artists/4STHEaNw4mPZ2tzheohgXB'},
#  {'artist_id': '4x1nvY2FN8jxqAFA0DA02H',
#   'artist_name': 'John Lennon',
#   'external_url': 'https://api.spotify.com/v1/artists/4x1nvY2FN8jxqAFA0DA02H'},
#  {'artist_id': '2s4tjL6W3qrblOe0raIzwJ',
#   'artist_name': 'Yoko Ono',
#   'external_url': 'https://api.spotify.com/v1/artists/2s4tjL6W3qrblOe0raIzwJ'},
#  {'artist_id': '1oSPZhvZMIrWW5I41kPkkY',
#   'artist_name': 'Jimin',
#   'external_url': 'https://api.spotify.com/v1/artists/1oSPZhvZMIrWW5I41kPkkY'},
#  {'artist_id': '5v8jlSmAQfrkTjAlpUfWtu',
#   'artist_name': 'Perry Como',
#   'external_url': 'https://api.spotify.com/v1/artists/5v8jlSmAQfrkTjAlpUfWtu'},
#  {'artist_id': '1Ml4OuStDoympbREURAM15',
#   'artist_name': 'The Fontane Sisters',
#   'external_url': 'https://api.spotify.com/v1/artists/1Ml4OuStDoympbREURAM15'},
#  {'artist_id': '0HS96tPggl2nwiz3gNWWI5',
#   'artist_name': 'Mitchell Ayres & His Orchestra',
#   'external_url': 'https://api.spotify.com/v1/artists/0HS96tPggl2nwiz3gNWWI5'},
#  {'artist_id': '6eUKZXaKkcviH0Ku9w2n3V',
#   'artist_name': 'Ed Sheeran',
#   'external_url': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V'},
#  {'artist_id': '3PhoLpVuITZKcymswpck5b',
#   'artist_name': 'Elton John',
#   'external_url': 'https://api.spotify.com/v1/artists/3PhoLpVuITZKcymswpck5b'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '7tYKF4w9nC0nq9CsPZTHyP',
#   'artist_name': 'SZA',
#   'external_url': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP'},
#  {'artist_id': '0wi4yTYlGtEnbGo4ltZTib',
#   'artist_name': "Shakin' Stevens",
#   'external_url': 'https://api.spotify.com/v1/artists/0wi4yTYlGtEnbGo4ltZTib'},
#  {'artist_id': '35S20clEkkSNUo23ViaslZ',
#   'artist_name': 'Band Aid',
#   'external_url': 'https://api.spotify.com/v1/artists/35S20clEkkSNUo23ViaslZ'},
#  {'artist_id': '3dRfiJ2650SZu6GbydcHNb',
#   'artist_name': 'John Williams',
#   'external_url': 'https://api.spotify.com/v1/artists/3dRfiJ2650SZu6GbydcHNb'},
#  {'artist_id': '391oLRVmoTkumiN79HkTWu',
#   'artist_name': 'Darlene Love',
#   'external_url': 'https://api.spotify.com/v1/artists/391oLRVmoTkumiN79HkTWu'},
#  {'artist_id': '1Mxqyy3pSjf8kZZL4QVxS0',
#   'artist_name': 'Frank Sinatra',
#   'external_url': 'https://api.spotify.com/v1/artists/1Mxqyy3pSjf8kZZL4QVxS0'},
#  {'artist_id': '0JXiS2FrAg3wQYJHcmZdrc',
#   'artist_name': 'B. Swanson Quartet',
#   'external_url': 'https://api.spotify.com/v1/artists/0JXiS2FrAg3wQYJHcmZdrc'},
#  {'artist_id': '5KEG7G8LDYlHgFDqZyEEs2',
#   'artist_name': 'Chris Rea',
#   'external_url': 'https://api.spotify.com/v1/artists/5KEG7G8LDYlHgFDqZyEEs2'},
#  {'artist_id': '1iCnM8foFssWlPRLfAbIwo',
#   'artist_name': 'Gigi Perez',
#   'external_url': 'https://api.spotify.com/v1/artists/1iCnM8foFssWlPRLfAbIwo'},
#  {'artist_id': '7gW0r5CkdEUMm42w9XpyZO',
#   'artist_name': 'Laufey',
#   'external_url': 'https://api.spotify.com/v1/artists/7gW0r5CkdEUMm42w9XpyZO'},
#  {'artist_id': '6ZjFtWeHP9XN7FeKSUe80S',
#   'artist_name': 'Bing Crosby',
#   'external_url': 'https://api.spotify.com/v1/artists/6ZjFtWeHP9XN7FeKSUe80S'},
#  {'artist_id': '69UfPJgUmFFAVT740qGVZi',
#   'artist_name': 'Ken Darby Singers',
#   'external_url': 'https://api.spotify.com/v1/artists/69UfPJgUmFFAVT740qGVZi'},
#  {'artist_id': '735L650pvygCZZlPMyHqsN',
#   'artist_name': 'John Scott Trotter & His Orchestra',
#   'external_url': 'https://api.spotify.com/v1/artists/735L650pvygCZZlPMyHqsN'},
#  {'artist_id': '43ZHCT0cAZBISjO8DG9PnE',
#   'artist_name': 'Elvis Presley',
#   'external_url': 'https://api.spotify.com/v1/artists/43ZHCT0cAZBISjO8DG9PnE'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '293zczrfYafIItmnmM3coR',
#   'artist_name': 'Chuck Berry',
#   'external_url': 'https://api.spotify.com/v1/artists/293zczrfYafIItmnmM3coR'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '699OTQXzgjhIYAHMy9RyPD',
#   'artist_name': 'Playboi Carti',
#   'external_url': 'https://api.spotify.com/v1/artists/699OTQXzgjhIYAHMy9RyPD'},
#  {'artist_id': '26AHtbjWKiwYzsoGoUZq53',
#   'artist_name': 'Pentatonix',
#   'external_url': 'https://api.spotify.com/v1/artists/26AHtbjWKiwYzsoGoUZq53'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '1Mxqyy3pSjf8kZZL4QVxS0',
#   'artist_name': 'Frank Sinatra',
#   'external_url': 'https://api.spotify.com/v1/artists/1Mxqyy3pSjf8kZZL4QVxS0'},
#  {'artist_id': '3eqjTLE0HfPfh78zjh6TqT',
#   'artist_name': 'Bruce Springsteen',
#   'external_url': 'https://api.spotify.com/v1/artists/3eqjTLE0HfPfh78zjh6TqT'},
#  {'artist_id': '3BmGtnKgCSGYIUhmivXKWX',
#   'artist_name': 'Kelly Clarkson',
#   'external_url': 'https://api.spotify.com/v1/artists/3BmGtnKgCSGYIUhmivXKWX'},
#  {'artist_id': '66CXWjxzNUsdJxJ2JdwvnR',
#   'artist_name': 'Ariana Grande',
#   'external_url': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR'},
#  {'artist_id': '3l9G1G9MxH6DaRhwLklaf5',
#   'artist_name': 'Oscar Maydon',
#   'external_url': 'https://api.spotify.com/v1/artists/3l9G1G9MxH6DaRhwLklaf5'},
#  {'artist_id': '0ys2OFYzWYB5hRDLCsBqxt',
#   'artist_name': 'Fuerza Regida',
#   'external_url': 'https://api.spotify.com/v1/artists/0ys2OFYzWYB5hRDLCsBqxt'},
#  {'artist_id': '11p2E654TTU8e0nZWBR4AL',
#   'artist_name': 'Mark Ambor',
#   'external_url': 'https://api.spotify.com/v1/artists/11p2E654TTU8e0nZWBR4AL'},
#  {'artist_id': '1Mxqyy3pSjf8kZZL4QVxS0',
#   'artist_name': 'Frank Sinatra',
#   'external_url': 'https://api.spotify.com/v1/artists/1Mxqyy3pSjf8kZZL4QVxS0'},
#  {'artist_id': '3oDbviiivRWhXwIE8hxkVV',
#   'artist_name': 'The Beach Boys',
#   'external_url': 'https://api.spotify.com/v1/artists/3oDbviiivRWhXwIE8hxkVV'},
#  {'artist_id': '3PhoLpVuITZKcymswpck5b',
#   'artist_name': 'Elton John',
#   'external_url': 'https://api.spotify.com/v1/artists/3PhoLpVuITZKcymswpck5b'},
#  {'artist_id': '790FomKkXshlbRYZFtlgla',
#   'artist_name': 'KAROL G',
#   'external_url': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla'}]

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
import pandas as pd
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                                         album_name  \
# 0  61ulfFSmmxMhc2wCdmdMkN                                    Merry Christmas
# 1  6egzU9NKfora01qaNbvwfZ                                     LAST CHRISTMAS
# 2  34wa3zf2prXFMk47t9zHFG                    Merry Christmas From Brenda Lee
# 3  3wivyOdotHWZ9dcuXMjPKT  Jingle Bell Rock/Captain Santa Claus (And His ...
# 4  10FLjwfpbxLmW8c25Xyc2N                                   Die With A Smile
#
#   album_release_date  album_total_tracks  \
# 0         1994-10-28                  10
# 1         1984-11-29                   3
# 2         1964-10-19                  12
# 3         1957-12-02                   2
# 4         2024-08-16                   1
#
#                                            album_url
# 0  https://open.spotify.com/album/61ulfFSmmxMhc2w...
# 1  https://open.spotify.com/album/6egzU9NKfora01q...
# 2  https://open.spotify.com/album/34wa3zf2prXFMk4...
# 3  https://open.spotify.com/album/3wivyOdotHWZ9dc...
# 4  https://open.spotify.com/album/10FLjwfpbxLmW8c...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            50 non-null     object
#  1   album_name          50 non-null     object
#  2   album_release_date  50 non-null     object
#  3   album_total_tracks  50 non-null     int64
#  4   album_url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df
# Out:
#                   album_id                                         album_name  \
# 0   61ulfFSmmxMhc2wCdmdMkN                                    Merry Christmas
# 1   6egzU9NKfora01qaNbvwfZ                                     LAST CHRISTMAS
# 2   34wa3zf2prXFMk47t9zHFG                    Merry Christmas From Brenda Lee
# 3   3wivyOdotHWZ9dcuXMjPKT  Jingle Bell Rock/Captain Santa Claus (And His ...
# 4   10FLjwfpbxLmW8c25Xyc2N                                   Die With A Smile
# 5   27MNgBEnLCKoafz1g2Zu97                                      Santa Tell Me
# 6   7kFyd5oyJdVX2pIi6P4iHE                                              rosie
# 7   5I48ENiZiaZZSOpec6PdS5                                   A Winter Romance
# 8   7Jahqd1kx9Qau0E9x9iZj6                                     Wrapped In Red
# 9   2vcGYJcPfXUmCdcXXqqukg             Everyday Is Christmas (Deluxe Edition)
# 10  4dcJHxlOJwtyypL7sx1qch                  The Andy Williams Christmas Album
# 11  3No96PtEFyRfX1oELmZTPu                                      Feliz Navidad
# 12  53fJVD9LpBKEMqdAF7PW5K                 Christmas (Deluxe Special Edition)
# 13  3aYOF3HVkIr1IzhePfQS7s                                        Sleigh Ride
# 14  0hBRqPYPXhr1RkTDG3n4Mk                          The Secret of Us (Deluxe)
# 15  7aJuG4TFXa2hmE4z1yxc3n                               HIT ME HARD AND SOFT
# 16  53fJVD9LpBKEMqdAF7PW5K                 Christmas (Deluxe Special Edition)
# 17  3NoP1ifIejWkGSDsO9T2xH                            The Nat King Cole Story
# 18  3cr4Xgz8nnfp7iYbVqwzzH                                Under The Mistletoe
# 19  48rypPDKdKiusMXKaYcEGV                     McCartney II (Special Edition)
# 20  555NIhJIQ4XoS5N7VglF0v                                      Signature Box
# 21  15XcLhiVMlSOipUddTNDnr                                               MUSE
# 22  4lculT3R9mxFqdmXOCLuY7                           Greatest Christmas Songs
# 23  3mJm77zryIt06nbQV7DjuY                            +-=÷× (Tour Collection)
# 24  1Ss0ArMRr91m83mOgRBjSZ                                                GNX
# 25  2jCRKrNZVbG2lGMs0S9Opa                           Merry Christmas Everyone
# 26  2WlRAsKdyYOwg2tdBjxVwq                       Do They Know It’s Christmas?
# 27  3rDo7fQDUwJ6qmxwP5yQsY    Home Alone (Original Motion Picture Soundtrack)
# 28  3miX7IkmfMBJhQejq5rsA6                 Christmas (Baby, Please Come Home)
# 29  2B9FcHKqz3PWJlh0yGnmM7                        The Classic Christmas Album
# 30  5tR0alqUd1KMW37vPnsOC4  Dancing with Strangers (Deluxe Edition, 2019 R...
# 31  68CN2LzY8MoxO2udy2C22e                                        Sailor Song
# 32  1Ph9nV8cNv7Gq7yHOlmbgh                            Spotify Singles Holiday
# 33  42KK3F8HTm1dyv5iFsCXdw                                    White Christmas
# 34  6zk4RKl6JFlgLCV4Z7DQ7N                             Elvis' Christmas Album
# 35  3iPSVi54hsacKKl1xIR2eH                                     Short n' Sweet
# 36  2D2boDrCPl6idtxpJF6r38                               A Nonsense Christmas
# 37  1DILNh7maaYyKxe15V9xLq                             Rock 'N' Roll Rarities
# 38  2IRxVVqbSbqHJo8Zx50LYn                                           Timeless
# 39  3sId8sOH47yqOWopzbEtJn                      A Pentatonix Christmas Deluxe
# 40  7aJuG4TFXa2hmE4z1yxc3n                               HIT ME HARD AND SOFT
# 41  0ny6mZMBrYSO0s8HAKbcVq               A Jolly Christmas From Frank Sinatra
# 42  6SEtGOi92yZM5TyAGlXlpZ  Santa Claus Is Comin' to Town (Live at C.W. Po...
# 43  5sVFXIMrFRKBtDOexVlBBU                     When Christmas Comes Around...
# 44  60cQzWfmdg4hyDXrpW6kOA                                            Tu Boda
# 45  1pSxnWkixgHxo9jnGK66nb          Run Rudolph Run - Spotify Singles Holiday
# 46  0ny6mZMBrYSO0s8HAKbcVq               A Jolly Christmas From Frank Sinatra
# 47  67nqYhvjDyJXGD64937Lw3                    The Beach Boys' Christmas Album
# 48  2R5dzEQT6MDsnwiZSpWgqC                          Caribou (Remastered 1995)
# 49  5ylbxH7EqpsmHZCRuiYewS                       Si Antes Te Hubiera Conocido
#
#    album_release_date  album_total_tracks  \
# 0          1994-10-28                  10
# 1          1984-11-29                   3
# 2          1964-10-19                  12
# 3          1957-12-02                   2
# 4          2024-08-16                   1
# 5          2014-11-24                   1
# 6          2024-12-06                  12
# 7          1959-01-01                  12
# 8          2013-10-29                  14
# 9          2018-11-01                  13
# 10         1963-11-24                  12
# 11         2002-09-24                  15
# 12         2011-10-24                  21
# 13         2020-12-04                  15
# 14         2024-10-18                  20
# 15         2024-05-17                  10
# 16         2011-10-24                  21
# 17         1961-09-25                  36
# 18         2011-01-01                  11
# 19         1980-05-16                  19
# 20         2010-10-05                 119
# 21         2024-07-19                   7
# 22         1999-08-23                  21
# 23         2024-09-27                  25
# 24         2024-11-21                  12
# 25         1991-11-25                  13
# 26         1984-11-25                   2
# 27               1990                  19
# 28         2020-12-04                  15
# 29               1945                  14
# 30         1987-08-02                  28
# 31         2024-07-26                   1
# 32         2023-11-14                   1
# 33         1945-01-01                  12
# 34         1957-10-15                  12
# 35         2024-08-23                  12
# 36         2022-12-07                   2
# 37         1986-01-01                  20
# 38         2024-09-27                   1
# 39         2017-12-06                  16
# 40         2024-05-17                  10
# 41            1957-09                  15
# 42               1981                   1
# 43         2021-10-15                  15
# 44         2024-09-26                   1
# 45         2024-10-15                   1
# 46            1957-09                  15
# 47         1964-11-09                  12
# 48         1974-06-28                  14
# 49         2024-06-21                   1
#
#                                             album_url
# 0   https://open.spotify.com/album/61ulfFSmmxMhc2w...
# 1   https://open.spotify.com/album/6egzU9NKfora01q...
# 2   https://open.spotify.com/album/34wa3zf2prXFMk4...
# 3   https://open.spotify.com/album/3wivyOdotHWZ9dc...
# 4   https://open.spotify.com/album/10FLjwfpbxLmW8c...
# 5   https://open.spotify.com/album/27MNgBEnLCKoafz...
# 6   https://open.spotify.com/album/7kFyd5oyJdVX2pI...
# 7   https://open.spotify.com/album/5I48ENiZiaZZSOp...
# 8   https://open.spotify.com/album/7Jahqd1kx9Qau0E...
# 9   https://open.spotify.com/album/2vcGYJcPfXUmCdc...
# 10  https://open.spotify.com/album/4dcJHxlOJwtyypL...
# 11  https://open.spotify.com/album/3No96PtEFyRfX1o...
# 12  https://open.spotify.com/album/53fJVD9LpBKEMqd...
# 13  https://open.spotify.com/album/3aYOF3HVkIr1Izh...
# 14  https://open.spotify.com/album/0hBRqPYPXhr1RkT...
# 15  https://open.spotify.com/album/7aJuG4TFXa2hmE4...
# 16  https://open.spotify.com/album/53fJVD9LpBKEMqd...
# 17  https://open.spotify.com/album/3NoP1ifIejWkGSD...
# 18  https://open.spotify.com/album/3cr4Xgz8nnfp7iY...
# 19  https://open.spotify.com/album/48rypPDKdKiusMX...
# 20  https://open.spotify.com/album/555NIhJIQ4XoS5N...
# 21  https://open.spotify.com/album/15XcLhiVMlSOipU...
# 22  https://open.spotify.com/album/4lculT3R9mxFqdm...
# 23  https://open.spotify.com/album/3mJm77zryIt06nb...
# 24  https://open.spotify.com/album/1Ss0ArMRr91m83m...
# 25  https://open.spotify.com/album/2jCRKrNZVbG2lGM...
# 26  https://open.spotify.com/album/2WlRAsKdyYOwg2t...
# 27  https://open.spotify.com/album/3rDo7fQDUwJ6qmx...
# 28  https://open.spotify.com/album/3miX7IkmfMBJhQe...
# 29  https://open.spotify.com/album/2B9FcHKqz3PWJlh...
# 30  https://open.spotify.com/album/5tR0alqUd1KMW37...
# 31  https://open.spotify.com/album/68CN2LzY8MoxO2u...
# 32  https://open.spotify.com/album/1Ph9nV8cNv7Gq7y...
# 33  https://open.spotify.com/album/42KK3F8HTm1dyv5...
# 34  https://open.spotify.com/album/6zk4RKl6JFlgLCV...
# 35  https://open.spotify.com/album/3iPSVi54hsacKKl...
# 36  https://open.spotify.com/album/2D2boDrCPl6idtx...
# 37  https://open.spotify.com/album/1DILNh7maaYyKxe...
# 38  https://open.spotify.com/album/2IRxVVqbSbqHJo8...
# 39  https://open.spotify.com/album/3sId8sOH47yqOWo...
# 40  https://open.spotify.com/album/7aJuG4TFXa2hmE4...
# 41  https://open.spotify.com/album/0ny6mZMBrYSO0s8...
# 42  https://open.spotify.com/album/6SEtGOi92yZM5Ty...
# 43  https://open.spotify.com/album/5sVFXIMrFRKBtDO...
# 44  https://open.spotify.com/album/60cQzWfmdg4hyDX...
# 45  https://open.spotify.com/album/1pSxnWkixgHxo9j...
# 46  https://open.spotify.com/album/0ny6mZMBrYSO0s8...
# 47  https://open.spotify.com/album/67nqYhvjDyJXGD6...
# 48  https://open.spotify.com/album/2R5dzEQT6MDsnwi...
# 49  https://open.spotify.com/album/5ylbxH7EqpsmHZC...

# %%
album_df['album_release_date']=pd.to_datetime(album_df['album_release_date'], format=None, errors='coerce' )
# Out:
# C:\Users\navee\AppData\Local\Temp\ipykernel_24716\2016057505.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   album_df['album_release_date']=pd.to_datetime(album_df['album_release_date'], format=None, errors='coerce' )

# %%
album_df=album_df.drop_duplicates(subset=['album_id'])

# %%
album_df
# Out:
#                   album_id                                         album_name  \
# 0   61ulfFSmmxMhc2wCdmdMkN                                    Merry Christmas
# 1   6egzU9NKfora01qaNbvwfZ                                     LAST CHRISTMAS
# 2   34wa3zf2prXFMk47t9zHFG                    Merry Christmas From Brenda Lee
# 3   3wivyOdotHWZ9dcuXMjPKT  Jingle Bell Rock/Captain Santa Claus (And His ...
# 4   10FLjwfpbxLmW8c25Xyc2N                                   Die With A Smile
# 5   27MNgBEnLCKoafz1g2Zu97                                      Santa Tell Me
# 6   7kFyd5oyJdVX2pIi6P4iHE                                              rosie
# 7   5I48ENiZiaZZSOpec6PdS5                                   A Winter Romance
# 8   7Jahqd1kx9Qau0E9x9iZj6                                     Wrapped In Red
# 9   2vcGYJcPfXUmCdcXXqqukg             Everyday Is Christmas (Deluxe Edition)
# 10  4dcJHxlOJwtyypL7sx1qch                  The Andy Williams Christmas Album
# 11  3No96PtEFyRfX1oELmZTPu                                      Feliz Navidad
# 12  53fJVD9LpBKEMqdAF7PW5K                 Christmas (Deluxe Special Edition)
# 13  3aYOF3HVkIr1IzhePfQS7s                                        Sleigh Ride
# 14  0hBRqPYPXhr1RkTDG3n4Mk                          The Secret of Us (Deluxe)
# 15  7aJuG4TFXa2hmE4z1yxc3n                               HIT ME HARD AND SOFT
# 17  3NoP1ifIejWkGSDsO9T2xH                            The Nat King Cole Story
# 18  3cr4Xgz8nnfp7iYbVqwzzH                                Under The Mistletoe
# 19  48rypPDKdKiusMXKaYcEGV                     McCartney II (Special Edition)
# 20  555NIhJIQ4XoS5N7VglF0v                                      Signature Box
# 21  15XcLhiVMlSOipUddTNDnr                                               MUSE
# 22  4lculT3R9mxFqdmXOCLuY7                           Greatest Christmas Songs
# 23  3mJm77zryIt06nbQV7DjuY                            +-=÷× (Tour Collection)
# 24  1Ss0ArMRr91m83mOgRBjSZ                                                GNX
# 25  2jCRKrNZVbG2lGMs0S9Opa                           Merry Christmas Everyone
# 26  2WlRAsKdyYOwg2tdBjxVwq                       Do They Know It’s Christmas?
# 27  3rDo7fQDUwJ6qmxwP5yQsY    Home Alone (Original Motion Picture Soundtrack)
# 28  3miX7IkmfMBJhQejq5rsA6                 Christmas (Baby, Please Come Home)
# 29  2B9FcHKqz3PWJlh0yGnmM7                        The Classic Christmas Album
# 30  5tR0alqUd1KMW37vPnsOC4  Dancing with Strangers (Deluxe Edition, 2019 R...
# 31  68CN2LzY8MoxO2udy2C22e                                        Sailor Song
# 32  1Ph9nV8cNv7Gq7yHOlmbgh                            Spotify Singles Holiday
# 33  42KK3F8HTm1dyv5iFsCXdw                                    White Christmas
# 34  6zk4RKl6JFlgLCV4Z7DQ7N                             Elvis' Christmas Album
# 35  3iPSVi54hsacKKl1xIR2eH                                     Short n' Sweet
# 36  2D2boDrCPl6idtxpJF6r38                               A Nonsense Christmas
# 37  1DILNh7maaYyKxe15V9xLq                             Rock 'N' Roll Rarities
# 38  2IRxVVqbSbqHJo8Zx50LYn                                           Timeless
# 39  3sId8sOH47yqOWopzbEtJn                      A Pentatonix Christmas Deluxe
# 41  0ny6mZMBrYSO0s8HAKbcVq               A Jolly Christmas From Frank Sinatra
# 42  6SEtGOi92yZM5TyAGlXlpZ  Santa Claus Is Comin' to Town (Live at C.W. Po...
# 43  5sVFXIMrFRKBtDOexVlBBU                     When Christmas Comes Around...
# 44  60cQzWfmdg4hyDXrpW6kOA                                            Tu Boda
# 45  1pSxnWkixgHxo9jnGK66nb          Run Rudolph Run - Spotify Singles Holiday
# 47  67nqYhvjDyJXGD64937Lw3                    The Beach Boys' Christmas Album
# 48  2R5dzEQT6MDsnwiZSpWgqC                          Caribou (Remastered 1995)
# 49  5ylbxH7EqpsmHZCRuiYewS                       Si Antes Te Hubiera Conocido
#
#    album_release_date  album_total_tracks  \
# 0          1994-10-28                  10
# 1          1984-11-29                   3
# 2          1964-10-19                  12
# 3          1957-12-02                   2
# 4          2024-08-16                   1
# 5          2014-11-24                   1
# 6          2024-12-06                  12
# 7          1959-01-01                  12
# 8          2013-10-29                  14
# 9          2018-11-01                  13
# 10         1963-11-24                  12
# 11         2002-09-24                  15
# 12         2011-10-24                  21
# 13         2020-12-04                  15
# 14         2024-10-18                  20
# 15         2024-05-17                  10
# 17         1961-09-25                  36
# 18         2011-01-01                  11
# 19         1980-05-16                  19
# 20         2010-10-05                 119
# 21         2024-07-19                   7
# 22         1999-08-23                  21
# 23         2024-09-27                  25
# 24         2024-11-21                  12
# 25         1991-11-25                  13
# 26         1984-11-25                   2
# 27                NaT                  19
# 28         2020-12-04                  15
# 29                NaT                  14
# 30         1987-08-02                  28
# 31         2024-07-26                   1
# 32         2023-11-14                   1
# 33         1945-01-01                  12
# 34         1957-10-15                  12
# 35         2024-08-23                  12
# 36         2022-12-07                   2
# 37         1986-01-01                  20
# 38         2024-09-27                   1
# 39         2017-12-06                  16
# 41                NaT                  15
# 42                NaT                   1
# 43         2021-10-15                  15
# 44         2024-09-26                   1
# 45         2024-10-15                   1
# 47         1964-11-09                  12
# 48         1974-06-28                  14
# 49         2024-06-21                   1
#
#                                             album_url
# 0   https://open.spotify.com/album/61ulfFSmmxMhc2w...
# 1   https://open.spotify.com/album/6egzU9NKfora01q...
# 2   https://open.spotify.com/album/34wa3zf2prXFMk4...
# 3   https://open.spotify.com/album/3wivyOdotHWZ9dc...
# 4   https://open.spotify.com/album/10FLjwfpbxLmW8c...
# 5   https://open.spotify.com/album/27MNgBEnLCKoafz...
# 6   https://open.spotify.com/album/7kFyd5oyJdVX2pI...
# 7   https://open.spotify.com/album/5I48ENiZiaZZSOp...
# 8   https://open.spotify.com/album/7Jahqd1kx9Qau0E...
# 9   https://open.spotify.com/album/2vcGYJcPfXUmCdc...
# 10  https://open.spotify.com/album/4dcJHxlOJwtyypL...
# 11  https://open.spotify.com/album/3No96PtEFyRfX1o...
# 12  https://open.spotify.com/album/53fJVD9LpBKEMqd...
# 13  https://open.spotify.com/album/3aYOF3HVkIr1Izh...
# 14  https://open.spotify.com/album/0hBRqPYPXhr1RkT...
# 15  https://open.spotify.com/album/7aJuG4TFXa2hmE4...
# 17  https://open.spotify.com/album/3NoP1ifIejWkGSD...
# 18  https://open.spotify.com/album/3cr4Xgz8nnfp7iY...
# 19  https://open.spotify.com/album/48rypPDKdKiusMX...
# 20  https://open.spotify.com/album/555NIhJIQ4XoS5N...
# 21  https://open.spotify.com/album/15XcLhiVMlSOipU...
# 22  https://open.spotify.com/album/4lculT3R9mxFqdm...
# 23  https://open.spotify.com/album/3mJm77zryIt06nb...
# 24  https://open.spotify.com/album/1Ss0ArMRr91m83m...
# 25  https://open.spotify.com/album/2jCRKrNZVbG2lGM...
# 26  https://open.spotify.com/album/2WlRAsKdyYOwg2t...
# 27  https://open.spotify.com/album/3rDo7fQDUwJ6qmx...
# 28  https://open.spotify.com/album/3miX7IkmfMBJhQe...
# 29  https://open.spotify.com/album/2B9FcHKqz3PWJlh...
# 30  https://open.spotify.com/album/5tR0alqUd1KMW37...
# 31  https://open.spotify.com/album/68CN2LzY8MoxO2u...
# 32  https://open.spotify.com/album/1Ph9nV8cNv7Gq7y...
# 33  https://open.spotify.com/album/42KK3F8HTm1dyv5...
# 34  https://open.spotify.com/album/6zk4RKl6JFlgLCV...
# 35  https://open.spotify.com/album/3iPSVi54hsacKKl...
# 36  https://open.spotify.com/album/2D2boDrCPl6idtx...
# 37  https://open.spotify.com/album/1DILNh7maaYyKxe...
# 38  https://open.spotify.com/album/2IRxVVqbSbqHJo8...
# 39  https://open.spotify.com/album/3sId8sOH47yqOWo...
# 41  https://open.spotify.com/album/0ny6mZMBrYSO0s8...
# 42  https://open.spotify.com/album/6SEtGOi92yZM5Ty...
# 43  https://open.spotify.com/album/5sVFXIMrFRKBtDO...
# 44  https://open.spotify.com/album/60cQzWfmdg4hyDX...
# 45  https://open.spotify.com/album/1pSxnWkixgHxo9j...
# 47  https://open.spotify.com/album/67nqYhvjDyJXGD6...
# 48  https://open.spotify.com/album/2R5dzEQT6MDsnwi...
# 49  https://open.spotify.com/album/5ylbxH7EqpsmHZC...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            47 non-null     object
#  1   album_name          47 non-null     object
#  2   album_release_date  43 non-null     datetime64[ns]
#  3   album_total_tracks  47 non-null     int64
#  4   album_url           47 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.2+ KB

# %%
import pandas as pd
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df=artist_df.drop_duplicates(subset=['artist_id'])

# %%
artist_df.head()
# Out:
#                 artist_id   artist_name  \
# 0  4iHNK0tOyZPYnBU7nGAgpQ  Mariah Carey
# 1  5lpH0xAS4fVfLkACg9DAuM         Wham!
# 2  4cPHsZM98sKzmV26wlwD2W    Brenda Lee
# 3  38EmEgXkgK51MT2tPY0EoC   Bobby Helms
# 4  1HY2Jd0NmPuamShAr6KMms     Lady Gaga
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/4iHNK0tOyZP...
# 1  https://api.spotify.com/v1/artists/5lpH0xAS4fV...
# 2  https://api.spotify.com/v1/artists/4cPHsZM98sK...
# 3  https://api.spotify.com/v1/artists/38EmEgXkgK5...
# 4  https://api.spotify.com/v1/artists/1HY2Jd0NmPu...

# %%
import pandas as pd
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df=song_df.drop_duplicates(subset=['song_id'])

# %%
song_df.head()
# Out:
#                   song_id                          song_name  duration_ms  \
# 0  0bYg9bo50gSsH3LtXe2SQn    All I Want for Christmas Is You       241106
# 1  2FRnf9qhLbvw8fu4IBXx78                     Last Christmas       262960
# 2  2EjXfH91m7f8HiJN1yQg97  Rockin' Around The Christmas Tree       126266
# 3  7vQbuQcyTflfCIOu3Uzzya                   Jingle Bell Rock       130973
# 4  2plbrEY59IikOBgBGLjaoe                   Die With A Smile       251667
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/0bYg9bo50gSsH3L...          78
# 1  https://open.spotify.com/track/2FRnf9qhLbvw8fu...          77
# 2  https://open.spotify.com/track/2EjXfH91m7f8HiJ...          76
# 3  https://open.spotify.com/track/7vQbuQcyTflfCIO...          74
# 4  https://open.spotify.com/track/2plbrEY59IikOBg...          97
#
#              song_added                album_id               artist_id
# 0  2024-12-31T01:43:34Z  61ulfFSmmxMhc2wCdmdMkN  4iHNK0tOyZPYnBU7nGAgpQ
# 1  2024-12-31T01:43:38Z  6egzU9NKfora01qaNbvwfZ  5lpH0xAS4fVfLkACg9DAuM
# 2  2024-12-31T01:43:44Z  34wa3zf2prXFMk47t9zHFG  4cPHsZM98sKzmV26wlwD2W
# 3  2024-12-31T01:43:50Z  3wivyOdotHWZ9dcuXMjPKT  38EmEgXkgK51MT2tPY0EoC
# 4  2024-12-31T01:43:54Z  10FLjwfpbxLmW8c25Xyc2N  1HY2Jd0NmPuamShAr6KMms

# %%
song_df['song_added']=pd.to_datetime(song_df['song_added'], format=None, errors='coerce' )

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.3+ KB

# %%
song_df.head()
# Out:
#                   song_id                          song_name  duration_ms  \
# 0  0bYg9bo50gSsH3LtXe2SQn    All I Want for Christmas Is You       241106
# 1  2FRnf9qhLbvw8fu4IBXx78                     Last Christmas       262960
# 2  2EjXfH91m7f8HiJN1yQg97  Rockin' Around The Christmas Tree       126266
# 3  7vQbuQcyTflfCIOu3Uzzya                   Jingle Bell Rock       130973
# 4  2plbrEY59IikOBgBGLjaoe                   Die With A Smile       251667
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/0bYg9bo50gSsH3L...          78
# 1  https://open.spotify.com/track/2FRnf9qhLbvw8fu...          77
# 2  https://open.spotify.com/track/2EjXfH91m7f8HiJ...          76
# 3  https://open.spotify.com/track/7vQbuQcyTflfCIO...          74
# 4  https://open.spotify.com/track/2plbrEY59IikOBg...          97
#
#                  song_added                album_id               artist_id
# 0 2024-12-31 01:43:34+00:00  61ulfFSmmxMhc2wCdmdMkN  4iHNK0tOyZPYnBU7nGAgpQ
# 1 2024-12-31 01:43:38+00:00  6egzU9NKfora01qaNbvwfZ  5lpH0xAS4fVfLkACg9DAuM
# 2 2024-12-31 01:43:44+00:00  34wa3zf2prXFMk47t9zHFG  4cPHsZM98sKzmV26wlwD2W
# 3 2024-12-31 01:43:50+00:00  3wivyOdotHWZ9dcuXMjPKT  38EmEgXkgK51MT2tPY0EoC
# 4 2024-12-31 01:43:54+00:00  10FLjwfpbxLmW8c25Xyc2N  1HY2Jd0NmPuamShAr6KMms
